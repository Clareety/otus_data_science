# %%
import pandas as pd 
import os
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline

# %% [markdown]
# Скачал данные с https://github.com/wesm/pydata-book/tree/2nd-edition/datasets/babynames
#
# План такой:
#
# 1) Получить названия директорий откуда пандас будет считывать файлы,
#
# 2) Путем танцев с бубнами, костылями и пандасами создать датафрейм,
#
# 3) Вытащить из названий файлов Год анализа,
#
# 4) Понять, что это даже не начало задания на визуализацию

# %%
yourpath = r'C:\Users\a.dikov\OTUS\5\datasets\babynames'

directory = []

for root, dirs, files in os.walk(yourpath, topdown=False):
    for name in files:
        directory.append(os.path.join(root, name))
        print(os.path.join(root, name))
#1 часть готова
# Out:
# C:\Users\a.dikov\OTUS\5\datasets\babynames\NationalReadMe.pdf
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1880.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1881.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1882.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1883.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1884.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1885.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1886.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1887.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1888.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1889.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1890.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1891.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1892.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1893.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1894.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1895.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1896.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1897.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1898.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1899.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1900.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1901.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1902.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1903.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1904.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1905.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1906.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1907.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1908.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1909.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1910.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1911.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1912.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1913.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1914.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1915.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1916.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1917.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1918.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1919.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1920.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1921.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1922.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1923.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1924.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1925.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1926.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1927.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1928.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1929.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1930.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1931.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1932.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1933.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1934.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1935.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1936.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1937.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1938.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1939.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1940.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1941.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1942.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1943.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1944.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1945.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1946.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1947.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1948.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1949.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1950.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1951.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1952.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1953.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1954.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1955.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1956.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1957.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1958.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1959.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1960.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1961.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1962.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1963.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1964.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1965.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1966.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1967.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1968.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1969.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1970.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1971.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1972.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1973.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1974.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1975.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1976.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1977.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1978.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1979.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1980.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1981.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1982.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1983.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1984.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1985.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1986.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1987.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1988.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1989.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1990.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1991.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1992.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1993.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1994.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1995.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1996.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1997.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1998.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob1999.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob2000.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob2001.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob2002.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob2003.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob2004.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob2005.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob2006.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob2007.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob2008.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob2009.txt
# C:\Users\a.dikov\OTUS\5\datasets\babynames\yob2010.txt

# %%
directory = directory[1:]
directory
#обрезаем для удобства
# Out:
# ['C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1880.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1881.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1882.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1883.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1884.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1885.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1886.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1887.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1888.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1889.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1890.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1891.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1892.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1893.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1894.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1895.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1896.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1897.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1898.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1899.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1900.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1901.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1902.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1903.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1904.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1905.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1906.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1907.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1908.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1909.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1910.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1911.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1912.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1913.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1914.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1915.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1916.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1917.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1918.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1919.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1920.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1921.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1922.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1923.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1924.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1925.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1926.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1927.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1928.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1929.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1930.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1931.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1932.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1933.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1934.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1935.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1936.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1937.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1938.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1939.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1940.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1941.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1942.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1943.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1944.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1945.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1946.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1947.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1948.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1949.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1950.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1951.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1952.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1953.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1954.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1955.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1956.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1957.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1958.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1959.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1960.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1961.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1962.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1963.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1964.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1965.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1966.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1967.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1968.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1969.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1970.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1971.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1972.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1973.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1974.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1975.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1976.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1977.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1978.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1979.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1980.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1981.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1982.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1983.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1984.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1985.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1986.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1987.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1988.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1989.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1990.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1991.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1992.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1993.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1994.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1995.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1996.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1997.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1998.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob1999.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob2000.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob2001.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob2002.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob2003.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob2004.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob2005.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob2006.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob2007.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob2008.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob2009.txt',
#  'C:\\Users\\a.dikov\\OTUS\\5\\datasets\\babynames\\yob2010.txt']

# %%
dfc = pd.DataFrame(columns=['Name','Sex','Amount','Year'])

for i in directory:
    df = pd.read_csv(i,names=['Name','Sex','Amount'], delimiter=',' )
    df['Year'] = i
    df['Year'] = df['Year'].map(lambda x: x.lstrip(r'C:\Users\a.dikov\OTUS\5\datasets\babynames\yob').rstrip('.txt'))
    dfc = dfc.append(df)

# 2 и 3 часть готовы

# %%
dfc
# Out:
#             Name Sex Amount  Year
# 0           Mary   F   7065  1880
# 1           Anna   F   2604  1880
# 2           Emma   F   2003  1880
# 3      Elizabeth   F   1939  1880
# 4         Minnie   F   1746  1880
# 5       Margaret   F   1578  1880
# 6            Ida   F   1472  1880
# 7          Alice   F   1414  1880
# 8         Bertha   F   1320  1880
# 9          Sarah   F   1288  1880
# 10         Annie   F   1258  1880
# 11         Clara   F   1226  1880
# 12          Ella   F   1156  1880
# 13      Florence   F   1063  1880
# 14          Cora   F   1045  1880
# 15        Martha   F   1040  1880
# 16         Laura   F   1012  1880
# 17        Nellie   F    995  1880
# 18         Grace   F    982  1880
# 19        Carrie   F    949  1880
# 20         Maude   F    858  1880
# 21         Mabel   F    808  1880
# 22        Bessie   F    794  1880
# 23        Jennie   F    793  1880
# 24      Gertrude   F    787  1880
# 25         Julia   F    783  1880
# 26        Hattie   F    769  1880
# 27         Edith   F    768  1880
# 28        Mattie   F    704  1880
# 29          Rose   F    700  1880
# ...          ...  ..    ...   ...
# 33808    Zaviyon   M      5  2010
# 33809   Zaybrien   M      5  2010
# 33810   Zayshawn   M      5  2010
# 33811     Zayyan   M      5  2010
# 33812       Zeal   M      5  2010
# 33813     Zealan   M      5  2010
# 33814   Zecharia   M      5  2010
# 33815   Zeferino   M      5  2010
# 33816   Zekariah   M      5  2010
# 33817       Zeki   M      5  2010
# 33818     Zeriah   M      5  2010
# 33819     Zeshan   M      5  2010
# 33820     Zhyier   M      5  2010
# 33821   Zildjian   M      5  2010
# 33822       Zinn   M      5  2010
# 33823     Zishan   M      5  2010
# 33824      Ziven   M      5  2010
# 33825      Zmari   M      5  2010
# 33826      Zoren   M      5  2010
# 33827     Zuhaib   M      5  2010
# 33828     Zyeire   M      5  2010
# 33829    Zygmunt   M      5  2010
# 33830   Zykerion   M      5  2010
# 33831      Zylar   M      5  2010
# 33832      Zylin   M      5  2010
# 33833    Zymaire   M      5  2010
# 33834     Zyonne   M      5  2010
# 33835  Zyquarius   M      5  2010
# 33836      Zyran   M      5  2010
# 33837      Zzyzx   M      5  2010
#
# [1690784 rows x 4 columns]

# %% [markdown]
# ЗАДАНИЕ 1: Сгруппируйте данные по полу и году и визуализируйте общую динамику
# рождаемости обоих полов

# %%
Sex_group = dfc.groupby(['Year', 'Sex']).sum()
Sex_group = Sex_group[['Amount']]
Sex_group
# Out:
#            Amount
# Year Sex
# 1880 F      90993
#      M     110493
# 1881 F      91955
#      M     100748
# 1882 F     107851
#      M     113687
# 1883 F     112322
#      M     104632
# 1884 F     129021
#      M     114445
# 1885 F     133056
#      M     107802
# 1886 F     144538
#      M     110785
# 1887 F     145983
#      M     101412
# 1888 F     178631
#      M     120857
# 1889 F     178369
#      M     110590
# 1890 F     190377
#      M     111026
# 1891 F     185486
#      M     101198
# 1892 F     212350
#      M     122038
# 1893 F     212908
#      M     112319
# 1894 F     222923
#      M     115775
# ...           ...
# 1996 F    1751681
#      M    1892700
# 1997 F    1739331
#      M    1883571
# 1998 F    1765390
#      M    1909676
# 1999 F    1772139
#      M    1918267
# 2000 F    1813960
#      M    1961702
# 2001 F    1798284
#      M    1940498
# 2002 F    1794358
#      M    1938941
# 2003 F    1824406
#      M    1972439
# 2004 F    1833005
#      M    1981557
# 2005 F    1843890
#      M    1993285
# 2006 F    1896468
#      M    2050234
# 2007 F    1916888
#      M    2069242
# 2008 F    1883645
#      M    2032310
# 2009 F    1827643
#      M    1973359
# 2010 F    1759010
#      M    1898382
#
# [262 rows x 1 columns]

# %%
plt.bar(Sex_group['
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-4b2cecba81ca> in <module>
#       1 a =23
# ----> 2 plt.bar(Sex_group,height=a )
#
# c:\users\a.dikov\appdata\local\programs\python\python36\lib\site-packages\matplotlib\pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2457     return gca().bar(
#    2458         x, height, width=width, bottom=bottom, align=align,
# -> 2459         **({"data": data} if data is not None else {}), **kwargs)
#    2460
#    2461
#
# c:\users\a.dikov\appdata\local\programs\python\python36\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# c:\users\a.dikov\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2294                 edgecolor=e,
#    2295                 linewidth=lw,
# -> 2296                 label='_nolegend_',
#    2297                 )
#    2298             r.update(kwargs)
#
# c:\users\a.dikov\appdata\local\programs\python\python36\lib\site-packages\matplotlib\patches.py in __init__(self, xy, width, height, angle, **kwargs)
#     656         """
#     657
# --> 658         Patch.__init__(self, **kwargs)
#     659
#     660         self._x0 = xy[0]
#
# c:\users\a.dikov\appdata\local\programs\python\python36\lib\site-packages\matplotlib\patches.py in __init__(self, edgecolor, facecolor, color, linewidth, linestyle, antialiased, hatch, fill, capstyle, joinstyle, **kwargs)
#      85         self.set_fill(fill)
#      86         self.set_linestyle(linestyle)
# ---> 87         self.set_linewidth(linewidth)
#      88         self.set_antialiased(antialiased)
#      89         self.set_hatch(hatch)
#
# c:\users\a.dikov\appdata\local\programs\python\python36\lib\site-packages\matplotlib\patches.py in set_linewidth(self, w)
#     346                 w = mpl.rcParams['axes.linewidth']
#     347
# --> 348         self._linewidth = float(w)
#     349         # scale the dash pattern by the linewidth
#     350         offset, ls = self._us_dashes
#
# TypeError: float() argument must be a string or a number, not 'NoneType'
